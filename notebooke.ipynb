# %%
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, CacheBackedEmbeddings
from langchain.vectorstores import FAISS
from langchain.storage import LocalFileStore
from langchain.chains import RetrievalQA

llm = ChatOpenAI()

cache_dir = LocalFileStore("./.cache/")

splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,
)
loader = UnstructuredFileLoader("./files/contract.txt")

docs = loader.load_and_split(text_splitter=splitter)

embeddings = OpenAIEmbeddings()

cached_embeddings = CacheBackedEmbeddings.from_bytes_store(embeddings, cache_dir)

vectorstore = FAISS.from_documents(docs, cached_embeddings)

chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever(),
)

chain.run("Describe Victory Mansions")
# Out:
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1006)>
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[1], line 20
#      13 splitter = CharacterTextSplitter.from_tiktoken_encoder(
#      14     separator="\n",
#      15     chunk_size=600,
#      16     chunk_overlap=100,
#      17 )
#      18 loader = UnstructuredFileLoader("./files/contract.txt")
# ---> 20 docs = loader.load_and_split(text_splitter=splitter)
#      22 embeddings = OpenAIEmbeddings()
#      24 cached_embeddings = CacheBackedEmbeddings.from_bytes_store(embeddings, cache_dir)
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/langchain/document_loaders/base.py:43, in BaseLoader.load_and_split(self, text_splitter)
#      41 else:
#      42     _text_splitter = text_splitter
# ---> 43 docs = self.load()
#      44 return _text_splitter.split_documents(docs)
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/langchain/document_loaders/unstructured.py:86, in UnstructuredBaseLoader.load(self)
#      84 def load(self) -> List[Document]:
#      85     """Load file."""
# ---> 86     elements = self._get_elements()
#      87     self._post_process_elements(elements)
#      88     if self.mode == "elements":
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/langchain/document_loaders/unstructured.py:172, in UnstructuredFileLoader._get_elements(self)
#     169 def _get_elements(self) -> List:
#     170     from unstructured.partition.auto import partition
# --> 172     return partition(filename=self.file_path, **self.unstructured_kwargs)
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/unstructured/partition/auto.py:338, in partition(filename, content_type, file, file_filename, url, include_page_breaks, strategy, encoding, paragraph_grouper, headers, skip_infer_table_types, ssl_verify, ocr_languages, languages, pdf_infer_table_structure, xml_keep_tags, data_source_metadata, metadata_filename, **kwargs)
#     327     elements = partition_image(
#     328         filename=filename,  # type: ignore
#     329         file=file,  # type: ignore
#    (...)
#     335         **kwargs,
#     336     )
#     337 elif filetype == FileType.TXT:
# --> 338     elements = partition_text(
#     339         filename=filename,
#     340         file=file,
#     341         encoding=encoding,
#     342         paragraph_grouper=paragraph_grouper,
#     343         **kwargs,
#     344     )
#     345 elif filetype == FileType.RTF:
#     346     _partition_rtf = _get_partition_with_extras("rtf")
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/unstructured/documents/elements.py:244, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     242 @functools.wraps(func)
#     243 def wrapper(*args, **kwargs):
# --> 244     elements = func(*args, **kwargs)
#     245     sig = inspect.signature(func)
#     246     params = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/unstructured/file_utils/filetype.py:541, in add_metadata_with_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     539 @wraps(func)
#     540 def wrapper(*args, **kwargs):
# --> 541     elements = func(*args, **kwargs)
#     542     sig = inspect.signature(func)
#     543     params = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/unstructured/chunking/title.py:197, in add_chunking_strategy.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     195 @wraps(func)
#     196 def wrapper(*args, **kwargs):
# --> 197     elements = func(*args, **kwargs)
#     198     sig = inspect.signature(func)
#     199     params = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/unstructured/partition/text.py:236, in partition_text(filename, file, text, encoding, paragraph_grouper, metadata_filename, include_metadata, max_partition, min_partition, metadata_last_modified, chunking_strategy, **kwargs)
#     233 if min_partition is not None and len(file_text) < min_partition:
#     234     raise ValueError("`min_partition` cannot be larger than the length of file contents.")
# --> 236 file_content = split_by_paragraph(
#     237     file_text,
#     238     min_partition=min_partition,
#     239     max_partition=max_partition,
#     240 )
#     242 elements: List[Element] = []
#     243 metadata = (
#     244     ElementMetadata(
#     245         filename=metadata_filename or filename,
#    (...)
#     249     else ElementMetadata()
#     250 )
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/unstructured/partition/text.py:51, in split_by_paragraph(file_text, min_partition, max_partition)
#      48 split_paragraphs = []
#      49 for paragraph in paragraphs:
#      50     split_paragraphs.extend(
# ---> 51         split_content_to_fit_max(
#      52             content=paragraph,
#      53             max_partition=max_partition,
#      54         ),
#      55     )
#      57 combined_paragraphs = combine_paragraphs_less_than_min(
#      58     split_paragraphs=split_paragraphs,
#      59     max_partition=max_partition,
#      60     min_partition=min_partition,
#      61 )
#      63 return combined_paragraphs
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/unstructured/partition/text.py:100, in split_content_to_fit_max(content, max_partition)
#      94 def split_content_to_fit_max(
#      95     content: str,
#      96     max_partition: Optional[int] = 1500,
#      97 ) -> List[str]:
#      98     """Splits a paragraph or section of content so that all of the elements fit into the
#      99     max partition window."""
# --> 100     sentences = sent_tokenize(content)
#     101     chunks = []
#     102     tmp_chunk = ""
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/unstructured/nlp/tokenize.py:30, in sent_tokenize(text)
#      28 """A wrapper around the NLTK sentence tokenizer with LRU caching enabled."""
#      29 _download_nltk_package_if_not_present(package_category="tokenizers", package_name="punkt")
# ---> 30 return _sent_tokenize(text)
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/nltk/tokenize/__init__.py:106, in sent_tokenize(text, language)
#      96 def sent_tokenize(text, language="english"):
#      97     """
#      98     Return a sentence-tokenized copy of *text*,
#      99     using NLTK's recommended sentence tokenizer
#    (...)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/nltk/data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     747     print(f"<<Loading {resource_url}>>")
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#     753     resource_val = opened_resource.read()
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/nltk/data.py:876, in _open(resource_url)
#     873 protocol, path_ = split_resource_url(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# --> 876     return find(path_, path + [""]).open()
#     877 elif protocol.lower() == "file":
#     878     # urllib might not use mode='rb', so handle this one ourselves:
#     879     return find(path_, [""]).open()
#
# File ~/DevProject/FULLSTACK-GPT/env/lib/python3.11/site-packages/nltk/data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/Users/whatsupjuno/nltk_data'
#     - '/Users/whatsupjuno/DevProject/FULLSTACK-GPT/env/nltk_data'
#     - '/Users/whatsupjuno/DevProject/FULLSTACK-GPT/env/share/nltk_data'
#     - '/Users/whatsupjuno/DevProject/FULLSTACK-GPT/env/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************
